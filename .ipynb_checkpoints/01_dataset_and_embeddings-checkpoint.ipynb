# %%
import sys
print(sys.executable)

# %%
import sys
# !{sys.executable} -m pip install sentence-transformers
# !{sys.executable} -m pip install faiss-cpu scikit-learn
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (5.2.3)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (0.33.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.7.1+cu118)
# Requirement already satisfied: numpy in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (2.3.0)
# Requirement already satisfied: scikit-learn in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.7.0)
# Requirement already satisfied: scipy in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: tqdm in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: filelock in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.6.15)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\RACHNA\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip
# Requirement already satisfied: faiss-cpu in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (1.13.2)
# Requirement already satisfied: scikit-learn in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from faiss-cpu) (2.3.0)
# Requirement already satisfied: packaging in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\RACHNA\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.13.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.3.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.10)
# Requirement already satisfied: pillow in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (11.2.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\RACHNA\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
# Out:
# C:\Users\RACHNA\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# WARNING:tensorflow:From C:\Users\RACHNA\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# !pip install sentence-transformers
# !pip install faiss-cpu
# !pip install scikit-learn
# !pip install pandas numpy matplotlib
# Out:
# Requirement already satisfied: sentence-transformers in C:\Users\RACHNA\miniconda3\Lib\site-packages (5.2.3)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: torch>=1.11.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: numpy in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (2.4.2)
# Requirement already satisfied: scikit-learn in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\RACHNA\miniconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.10.0)
# Requirement already satisfied: certifi in C:\Users\RACHNA\miniconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\RACHNA\miniconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\RACHNA\miniconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\RACHNA\miniconda3\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.10.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\RACHNA\miniconda3\Lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: click>=8.0.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Requirement already satisfied: faiss-cpu in C:\Users\RACHNA\miniconda3\Lib\site-packages (1.13.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from faiss-cpu) (2.4.2)
# Requirement already satisfied: packaging in C:\Users\RACHNA\miniconda3\Lib\site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: scikit-learn in C:\Users\RACHNA\miniconda3\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas in C:\Users\RACHNA\miniconda3\Lib\site-packages (3.0.1)
# Requirement already satisfied: numpy in C:\Users\RACHNA\miniconda3\Lib\site-packages (2.4.2)
# Requirement already satisfied: matplotlib in C:\Users\RACHNA\miniconda3\Lib\site-packages (3.10.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\RACHNA\miniconda3\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install sentence-transformers faiss-cpu scikit-learn
# Out:
# Requirement already satisfied: sentence-transformers in C:\Users\RACHNA\miniconda3\Lib\site-packages (5.2.3)
# Requirement already satisfied: faiss-cpu in C:\Users\RACHNA\miniconda3\Lib\site-packages (1.13.2)
# Requirement already satisfied: scikit-learn in C:\Users\RACHNA\miniconda3\Lib\site-packages (1.8.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: torch>=1.11.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: numpy in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (2.4.2)
# Requirement already satisfied: scipy in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\RACHNA\miniconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.10.0)
# Requirement already satisfied: certifi in C:\Users\RACHNA\miniconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\RACHNA\miniconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\RACHNA\miniconda3\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\RACHNA\miniconda3\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.10.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\RACHNA\miniconda3\Lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: click>=8.0.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\RACHNA\miniconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)

# %%
import numpy as np
import pandas as pd
import re

from sklearn.datasets import fetch_20newsgroups
from sentence_transformers import SentenceTransformer

# %%
dataset = fetch_20newsgroups(
    subset="all",
    remove=("headers", "footers", "quotes")
)

documents = dataset.data
labels = dataset.target

print("Total documents:", len(documents))
print("Number of categories:", len(dataset.target_names))
# Out:
# Total documents: 18846
# Number of categories: 20

# %%
print(documents[0][:500])
# Out:
# I am sure some bashers of Pens fans are pretty confused about the lack
# of any kind of posts about the recent Pens massacre of the Devils. Actually,
# I am  bit puzzled too and a bit relieved. However, I am going to put an end
# to non-PIttsburghers' relief with a bit of praise for the Pens. Man, they
# are killing those Devils worse than I thought. Jagr just showed you why
# he is much better than his regular season stats. He is also a lot
# fo fun to watch in the playoffs. Bowman should let JAgr have a

# %%
def clean_text(text):

    text = text.lower()

    # remove email addresses
    text = re.sub(r'\S+@\S+', '', text)

    # remove urls
    text = re.sub(r'http\S+|www\S+', '', text)

    # remove special characters but keep letters, numbers, spaces
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)

    # remove extra spaces
    text = re.sub(r'\s+', ' ', text)

    return text.strip()

# %%
clean_documents = [clean_text(doc) for doc in documents]

print(clean_documents[0][:500])
# Out:
# i am sure some bashers of pens fans are pretty confused about the lack of any kind of posts about the recent pens massacre of the devils actually i am bit puzzled too and a bit relieved however i am going to put an end to non pittsburghers relief with a bit of praise for the pens man they are killing those devils worse than i thought jagr just showed you why he is much better than his regular season stats he is also a lot fo fun to watch in the playoffs bowman should let jagr have a lot of fun i

# %%
with open("clean_documents.txt", "w", encoding="utf-8") as f:
    for doc in clean_documents:
        f.write(doc.replace("\n", " ") + "\n")

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
embeddings = model.encode(
    clean_documents,
    show_progress_bar=True
)
# Out:
# Batches:   0%|          | 0/589 [00:00<?, ?it/s]

# %%
print(embeddings.shape)
# Out:
# (18846, 384)

# %%
import faiss

# %%
embeddings = embeddings.astype("float32")

# %%
dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)

# %%
index.add(embeddings)

print("Total vectors stored:", index.ntotal)
# Out:
# Total vectors stored: 18846

# %%
query = "space exploration and nasa missions"

query_embedding = model.encode([query]).astype("float32")

distances, indices = index.search(query_embedding, k=5)

for i in indices[0]:
    print(clean_documents[i][:300])
    print("\n-----------------\n")
# Out:
# the aiaa san gabriel valley section is sponsoring the following lecture on mars exploration at the jet propulsion lab admission is free and open to the public the next frontier the challenge of mars exploration date may 6 1993 time 6 00pm 8 30 pm location von karman auditorium jet propulsion lab 480
#
# -----------------
#
# i know that alot of how people think and act in a long distance space project would be much like old tiem explorers sailors hunters and such who spent alot of time alone isolated and alone or in minimal surroundings and sopcial contacts such as the old arctic and antarctic expeditions and such i vot
#
# -----------------
#
# lets hear it for dan goldin now if he can only convince the rest of our federal government that the space program is a worth while investment i hope that i will live to see the day we walk on mars but we need to address the technical hurdles first if there s sufficient interest maybe we should consi
#
# -----------------
#
# we ve been progressing towards that goal for 30 years now we precede any orbiting mission with flyby missions of course it gets harder to do as we work our way farther away from earth we re just starting to work out to the outer planets galileo will orbit jupiter and cassini around saturn
#
# -----------------
#
# we are not at the end of the space age but only at the end of its beginning that space exploration is no longer a driver for technical innovation or a focus of american cultural attention is certainly debatable however technical developments in other quarters will always be examined for possible app
#
# -----------------

# %%
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture

# %%
pca = PCA(n_components=50, random_state=42)

reduced_embeddings = pca.fit_transform(embeddings)

print(reduced_embeddings.shape)
# Out:
# (18846, 50)

# %%
bic_scores = []
cluster_range = range(5, 30)

for k in cluster_range:
    gmm = GaussianMixture(n_components=k, random_state=42)
    gmm.fit(reduced_embeddings)
    bic_scores.append(gmm.bic(reduced_embeddings))

# %%
best_k = cluster_range[np.argmin(bic_scores)]

print("Best number of clusters:", best_k)
# Out:
# Best number of clusters: 11

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_features=5000,
    stop_words="english"
)

tfidf_matrix = vectorizer.fit_transform(clean_documents)

feature_names = vectorizer.get_feature_names_out()

# %%
cluster_probabilities = gmm.predict_proba(reduced_embeddings)

print(cluster_probabilities.shape)
# Out:
# (18846, 29)

# %%
cluster_labels = cluster_probabilities.argmax(axis=1)

# %%
import numpy as np

for cluster in range(best_k):

    print("\nCluster", cluster)

    cluster_docs = np.where(cluster_labels == cluster)[0]

    cluster_tfidf = tfidf_matrix[cluster_docs].mean(axis=0)

    top_words = np.argsort(cluster_tfidf).tolist()[0][-10:]

    for word in reversed(top_words):
        print(feature_names[word])
# Out:
# Cluster 0
# drive
# scsi
# disk
# drives
# ide
# hard
# controller
# disks
# mac
# floppy
#
# Cluster 1
# space
# orbit
# shuttle
# nasa
# launch
# moon
# earth
# like
# mission
# just
#
# Cluster 2
# mail
# address
# thanks
# know
# list
# send
# email
# information
# like
# computer
#
# Cluster 3
# government
# people
# clinton
# don
# just
# like
# tax
# think
# president
# drugs
#
# Cluster 4
# zone
# zip
# zionist
# zero
# zealand
# z5
# yx
# yugoslavia
# youth
# young
#
# Cluster 5
# god
# believe
# people
# religion
# don
# atheism
# say
# atheists
# think
# faith
#
# Cluster 6
# windows
# dos
# file
# mouse
# program
# os
# use
# files
# problem
# ms
#
# Cluster 7
# just
# don
# think
# like
# post
# article
# know
# say
# said
# ax
#
# Cluster 8
# window
# server
# motif
# xterm
# application
# use
# display
# widget
# x11r5
# windows
#
# Cluster 9
# bike
# car
# ride
# riding
# just
# dod
# don
# dog
# road
# helmet
#
# Cluster 10
# printer
# print
# fonts
# windows
# hp
# laser
# printers
# font
# printing
# driver

# %%
confidence = cluster_probabilities.max(axis=1)

# %%
boundary_docs = np.argsort(confidence)[:10]

# %%
for i in boundary_docs:
    
    print("\nDocument ID:", i)
    print("Cluster probabilities:", cluster_probabilities[i])
    print("\nText:")
    print(clean_documents[i][:400])
    print("\n-----------------------------\n")
# Out:
# Document ID: 6796
# Cluster probabilities: [7.70627025e-07 3.75957228e-25 1.46646265e-10 1.26116862e-44
#  0.00000000e+00 0.00000000e+00 1.11930139e-01 6.09668735e-25
#  4.46375459e-01 4.91305556e-30 2.80416662e-05 4.41552162e-01
#  0.00000000e+00 7.61469135e-14 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.18917918e-23 4.98547382e-39 2.81548528e-05
#  1.08238661e-11 0.00000000e+00 1.02714674e-19 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 9.03042132e-39 0.00000000e+00
#  8.29457640e-05]
#
# Text:
# it isn t use tar on the un x box and gtak110 zip on the dos box needs aspi driver ralf
#
# -----------------------------
#
#
# Document ID: 2652
# Cluster probabilities: [9.32976918e-25 2.18094154e-11 4.54266995e-01 5.83695825e-15
#  0.00000000e+00 0.00000000e+00 2.39870301e-21 2.96785838e-12
#  4.13960298e-32 4.62146431e-01 5.77728832e-27 9.80577218e-21
#  0.00000000e+00 1.94453065e-10 1.27062193e-36 2.04012819e-30
#  4.05843012e-35 9.92254820e-03 4.86289910e-22 1.03058424e-20
#  7.36647695e-02 2.64988369e-19 1.87103783e-19 6.74829635e-38
#  0.00000000e+00 0.00000000e+00 8.12292664e-11 7.25423848e-31
#  5.13706537e-23]
#
# Text:
# hi me and my roomate are going to redecorate the living room and we thought it would be a cool idea to have a license plate from every state in the us and then from whereever else we could find like canada mexixo even some european ones if anyone has any ideas or knows someone that could help us out please let me know the more recent the better but anything would be nice either that or if you have
#
# -----------------------------
#
#
# Document ID: 3092
# Cluster probabilities: [0.00000000e+00 1.17002121e-20 4.05035280e-07 1.78382769e-01
#  0.00000000e+00 2.51789372e-02 0.00000000e+00 4.75360006e-01
#  0.00000000e+00 1.84950428e-15 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.20835637e-32 1.09998184e-10 1.95055171e-14
#  3.21077079e-01 1.33657412e-26 4.64257733e-17 0.00000000e+00
#  5.02913968e-39 1.99363526e-09 1.64955754e-23 5.18672105e-10
#  3.61331058e-33 1.03281115e-29 4.84609531e-25 1.08411960e-38
#  0.00000000e+00]
#
# Text:
# is this group for real i honestly can t believe that most of you expect you or your concerns to be taken remotely seriously if you behave this way in a forum for discussion doesn t it ever occur to those of you who write letters like the majority of those in this group that you re being mind bogglingly hypocritical
#
# -----------------------------
#
#
# Document ID: 6489
# Cluster probabilities: [0.0000000e+00 4.3346713e-27 7.8826342e-24 3.6967628e-14 0.0000000e+00
#  1.7413759e-01 0.0000000e+00 9.6664787e-10 2.8025969e-45 6.5630149e-31
#  0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 7.2218443e-18
#  3.3813214e-13 3.4548533e-01 0.0000000e+00 1.8933392e-26 0.0000000e+00
#  3.8398159e-38 5.6599507e-27 5.6051939e-45 4.8037666e-01 0.0000000e+00
#  4.1420091e-37 0.0000000e+00 0.0000000e+00 0.0000000e+00]
#
# Text:
# that s right everyone even infants who cannot speak as yet even a little child will rebelliously stick his finger in a light socket even a little child will not want his diaper changed even a little child will fight nap time so far as jesus saying everyone a certain ruler asked jesus good teacher what must i do to inherit eternal life why do you call me good jesus answered no one is good except go
#
# -----------------------------
#
#
# Document ID: 8768
# Cluster probabilities: [2.3657194e-11 9.6959092e-18 1.1929515e-06 2.1400810e-33 0.0000000e+00
#  0.0000000e+00 2.4343009e-08 9.2868800e-24 6.3754237e-09 8.1664976e-23
#  4.4740207e-07 1.0289059e-07 0.0000000e+00 2.7207807e-01 0.0000000e+00
#  0.0000000e+00 0.0000000e+00 1.0370917e-12 1.2968692e-29 4.8291397e-01
#  2.2206450e-01 0.0000000e+00 2.1552766e-27 0.0000000e+00 0.0000000e+00
#  0.0000000e+00 4.3559965e-31 0.0000000e+00 2.2941519e-02]
#
# Text:
# hello i am looking for a hp28s or hp28sx calculator if anyone has one they are getting rid of please let me know reply to thanks jeremy
#
# -----------------------------
#
#
# Document ID: 16900
# Cluster probabilities: [1.35100615e-08 2.97101251e-05 4.30338492e-04 4.87817772e-12
#  0.00000000e+00 1.35140064e-19 4.86556739e-01 8.25608240e-08
#  2.89234426e-03 2.29873409e-09 2.24906738e-09 3.68141616e-03
#  6.31495549e-33 9.31127536e-11 1.51099033e-23 1.35838434e-25
#  8.56599848e-22 8.34505798e-08 1.11638556e-07 2.31309891e-01
#  2.75098383e-01 4.03722319e-23 2.58315480e-10 3.30681222e-21
#  2.92453738e-28 2.93062332e-36 2.52354805e-17 3.61611156e-32
#  4.30698532e-10]
#
# Text:
# im designing a circuit with just a silicon diode i dont need to modify any of the parameters but the problem will not accept the following statement model diode d the pspice book i have is terrible i would appreciate any help
#
# -----------------------------
#
#
# Document ID: 15204
# Cluster probabilities: [1.68155816e-44 1.42035397e-08 4.97455209e-01 1.47821207e-03
#  0.00000000e+00 1.30385155e-17 8.51415918e-24 5.01062334e-01
#  5.39621111e-27 2.17710008e-12 2.66246708e-44 2.13047630e-19
#  7.00501473e-27 2.04381943e-16 1.98390381e-07 6.95222907e-11
#  2.72578715e-09 6.88411242e-19 1.38629705e-17 3.76030445e-32
#  9.40980551e-23 7.14361697e-18 2.59747819e-21 1.12919668e-06
#  1.67389574e-19 8.91571295e-14 3.13512919e-06 3.94138195e-17
#  1.57772194e-41]
#
# Text:
# please post to news too
#
# -----------------------------
#
#
# Document ID: 4408
# Cluster probabilities: [0.0000000e+00 4.8791107e-11 1.6001064e-07 1.6960078e-10 0.0000000e+00
#  1.2444106e-08 1.3305033e-29 4.9866736e-01 1.6333055e-27 1.1724857e-23
#  0.0000000e+00 1.1150542e-28 3.1248956e-43 8.8268187e-24 1.6064940e-19
#  7.3701848e-14 4.4200924e-22 9.9099648e-23 7.6182534e-17 1.9127919e-29
#  1.6215291e-19 3.2437104e-26 2.3804312e-25 5.0133193e-01 8.4345556e-41
#  3.9029498e-11 3.6857991e-26 7.2867520e-44 0.0000000e+00]
#
# Text:
# the oed gives the etymology of sibyl as coming from the ancient greek sigma iota beta upsilon lambda lambda alpha s i b ih l l a which is claimed to come from the doric sigma iota omicron beta upsilon lambda lambda alpha s i o b ih l l a which if i read it properly in turn came from the attican athenian theta epsilon omicron beta omicron upsilon lambda eta th eh o b o ih l ae i don t know much abo
#
# -----------------------------
#
#
# Document ID: 773
# Cluster probabilities: [0.0000000e+00 1.5498453e-17 1.7470302e-10 5.5824178e-03 0.0000000e+00
#  3.5260997e-16 8.9450683e-35 7.0601857e-08 0.0000000e+00 7.9302825e-03
#  0.0000000e+00 0.0000000e+00 9.8039866e-34 9.6175025e-29 4.0738008e-13
#  2.4330140e-05 4.8447314e-01 4.9343368e-22 1.2578458e-15 0.0000000e+00
#  1.6512708e-22 5.0198829e-01 2.2496277e-14 3.9212583e-16 1.0108112e-31
#  6.0163047e-27 1.8116492e-24 1.7650717e-23 0.0000000e+00]
#
# Text:
# of course you are a bunch of arrogant lawyers who know whats best for the rest of us you are doing such a wonderful job with our judicial system getting all the criminals off i bow to your superior intellect not to mention the fees you collect from us poor slobs who get tickets from speeding state police officers so you can soak is when we go to court i just love lawyer jokes don t you
#
# -----------------------------
#
#
# Document ID: 4849
# Cluster probabilities: [0.00000000e+00 5.02373338e-01 2.76864946e-01 2.20744386e-01
#  0.00000000e+00 1.08003405e-29 3.00906811e-24 1.88083359e-05
#  2.10237179e-35 2.97423544e-11 0.00000000e+00 2.49609753e-18
#  4.27396032e-43 1.69964242e-16 6.64206192e-20 3.33941964e-19
#  6.88466767e-18 1.17298489e-11 3.60745563e-19 1.00424427e-28
#  1.78240627e-16 5.61546032e-10 2.10948460e-17 3.54592391e-26
#  6.58422304e-33 5.43752962e-38 4.09123970e-07 3.69698883e-21
#  1.08796813e-41]
#
# Text:
# the following flyer was distributed at aipac s 34th annual policy conference
#
# -----------------------------

# %%
semantic_cache = {
    cluster: {
        "queries": [],
        "embeddings": [],
        "results": []
    }
    for cluster in range(best_k)
}

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def search_cache(query_embedding, cluster):

    cache = semantic_cache[cluster]

    if len(cache["embeddings"]) == 0:
        return None

    similarities = cosine_similarity(
        query_embedding,
        cache["embeddings"]
    )[0]

    best_match = similarities.argmax()
    best_score = similarities[best_match]

    if best_score > SIMILARITY_THRESHOLD:
        return cache["results"][best_match]

    return None

# %%
def add_to_cache(query, query_embedding, results):

    semantic_cache["queries"].append(query)

    semantic_cache["embeddings"].append(query_embedding[0])

    semantic_cache["results"].append(results)

# %%
def semantic_search(query):

    query_embedding = model.encode([query]).astype("float32")

    cluster = get_query_cluster(query_embedding)

    cached_result = search_cache(query_embedding, cluster)

    if cached_result is not None:
        print("CACHE HIT")
        return cached_result

    print("CACHE MISS")

    distances, indices = index.search(query_embedding, k=5)

    results = [clean_documents[i] for i in indices[0]]

    semantic_cache[cluster]["queries"].append(query)
    semantic_cache[cluster]["embeddings"].append(query_embedding[0])
    semantic_cache[cluster]["results"].append(results)

    return results

# %%
def get_query_cluster(query_embedding):
    
    query_reduced = pca.transform(query_embedding)
    
    probs = gmm.predict_proba(query_reduced)
    
    cluster = probs.argmax(axis=1)[0]
    
    return cluster

# %%
SIMILARITY_THRESHOLD = 0.6

# %%
result1 = semantic_search("mars exploration missions")

result2 = semantic_search("nasa missions to mars")
# Out:
# CACHE MISS
# CACHE HIT (similarity=0.900)

# %%
semantic_cache = {
    cluster: {
        "queries": [],
        "embeddings": [],
        "results": []
    }
    for cluster in range(best_k)
}

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def search_cache(query_embedding, cluster):

    cache = semantic_cache.setdefault(cluster, {
    "queries": [],
    "embeddings": [],
    "results": []
})

    if len(cache["embeddings"]) == 0:
        return None

    similarities = cosine_similarity(
        query_embedding,
        cache["embeddings"]
    )[0]

    best_match = similarities.argmax()
    best_score = similarities[best_match]

    if best_score > SIMILARITY_THRESHOLD:
        print(f"CACHE HIT (similarity={best_score:.3f})")
        return cache["results"][best_match]

    return None

# %%
def add_to_cache(query, query_embedding, results, cluster):

    semantic_cache[cluster]["queries"].append(query)
    semantic_cache[cluster]["embeddings"].append(query_embedding[0])
    semantic_cache[cluster]["results"].append(results)

# %%
def semantic_search(query):

    query_embedding = model.encode([query]).astype("float32")

    cluster = get_query_cluster(query_embedding)

    cached_result = search_cache(query_embedding, cluster)

    if cached_result is not None:
        return cached_result

    print("CACHE MISS")

    distances, indices = index.search(query_embedding, k=5)

    results = [clean_documents[i] for i in indices[0]]

    add_to_cache(query, query_embedding, results, cluster)

    return results

# %%
r1 = semantic_search("mars exploration missions")

r2 = semantic_search("nasa missions to mars")

r3 = semantic_search("hockey team players")

print(r3[0][:300])
# Out:
# CACHE MISS
# CACHE HIT (similarity=0.900)
# CACHE MISS
# this is an all point team for the canadian nhlers who are not playoff bound goalies bill ranford edmonton sean burke hartford peter sidorkiewicz ottawa defensemen zarley zalapski hartford norm maciver ottawa garry galley philadelphia greg hawgood philadelphia dave manson edmonton mark tinordi minnes

# %%
pip install fastapi uvicorn
# Out:
# Requirement already satisfied: fastapi in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (0.117.1)
# Requirement already satisfied: uvicorn in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (0.37.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from fastapi) (0.48.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from fastapi) (2.11.9)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from fastapi) (4.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from starlette<0.49.0,>=0.40.0->fastapi) (4.9.0)
# Requirement already satisfied: idna>=2.8 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: click>=7.0 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from uvicorn) (8.2.1)
# Requirement already satisfied: h11>=0.8 in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: colorama in c:\users\rachna\appdata\local\programs\python\python311\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\RACHNA\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
# imports
from fastapi import FastAPI
from pydantic import BaseModel
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# load model
model = SentenceTransformer("all-MiniLM-L6-v2")

# load dataset
with open("clean_documents.txt", "r", encoding="utf-8") as f:
    clean_documents = [line.strip() for line in f]

# create embeddings
embeddings = model.encode(clean_documents).astype("float32")

# build FAISS index
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# clustering setup
best_k = 10

semantic_cache = {
    cluster: {
        "queries": [],
        "embeddings": [],
        "results": []
    }
    for cluster in range(best_k)
}


# ------------------------------------------------
# FASTAPI APP
# ------------------------------------------------

app = FastAPI()


# stats
total_entries = 0
hit_count = 0
miss_count = 0


class QueryRequest(BaseModel):
    query: str


# ------------------------------------------------
# API ROUTES
# ------------------------------------------------

@app.post("/query")
def query_endpoint(request: QueryRequest):

    global hit_count, miss_count, total_entries

    query = request.query

    query_embedding = model.encode([query]).astype("float32")

    cluster = get_query_cluster(query_embedding)

    cached_result = search_cache(query_embedding, cluster)

    if cached_result is not None:
        hit_count += 1

        return {
            "query": query,
            "cache_hit": True,
            "result": cached_result,
            "dominant_cluster": int(cluster)
        }

    miss_count += 1

    distances, indices = index.search(query_embedding, k=5)

    results = [clean_documents[i] for i in indices[0]]

    add_to_cache(query, query_embedding, results, cluster)

    total_entries = sum(len(semantic_cache[c]["queries"]) for c in semantic_cache)

    return {
        "query": query,
        "cache_hit": False,
        "result": results,
        "dominant_cluster": int(cluster)
    }


@app.get("/cache/stats")
def cache_stats():

    total = hit_count + miss_count
    hit_rate = (hit_count / total) * 100 if total > 0 else 0

    return {
        "total_entries": total_entries,
        "hit_count": hit_count,
        "miss_count": miss_count,
        "hit_rate": f"{hit_rate:.2f}%"
    }


@app.delete("/cache")
def clear_cache():

    global semantic_cache, hit_count, miss_count, total_entries

    semantic_cache = {
        cluster: {
            "queries": [],
            "embeddings": [],
            "results": []
        }
        for cluster in range(best_k)
    }

    hit_count = 0
    miss_count = 0
    total_entries = 0

    return {"message": "Cache cleared"}
